# %% [markdown]
# # Welcome to the SimpleITK Image Filtering Tutorial
#
# This tutorial illustrates how to use some of the basic image filtering capabilities of SimpleITK.

# %% [markdown]
# ## Importing SimpleITK
# We start by importing the SimpleITK python module

# %%
import SimpleITK as sitk

# %% [markdown]
# ## Downloading an Image
#
# We download a specific image from the Figshare data sharing and hosting site

# %%
import urllib
import os.path

destination = '/tmp/TralitusSaltrator.jpg'
source = 'http://files.figshare.com/1546044/IMG_0974.jpg'

# %% [markdown]
# and we download the image file, only if it doesn't already exist in our local disk

# %%
if not os.path.isfile(destination):
    urllib.urlretrieve(source,destination)

# %% [markdown]
# ## Reading an Image
#
# Then we read in an image

# %%
colorimage = sitk.ReadImage(destination)

# %% [markdown]
# ## Converting to Grayscale
#
# Typical image fileformats such as PNG and JPG will be read as color images (three channels matching RGB components).

# %%
image = sitk.VectorMagnitude(colorimage)

# %% [markdown]
# ## Displaying the Image
#
# We extract the pixel data in the form of a numpy array, that then we visualize using the Matplotlib python module

# %%
imshow(sitk.GetArrayFromImage(image));

# %% [markdown]
# ### Changing the Colormap
#
# By default, imshow would use a rainbow colormap. We can change that by selecting from
# http://wiki.scipy.org/Cookbook/Matplotlib/Show_colormaps

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

imshow(sitk.GetArrayFromImage(image),cmap=cm.gray);

# %% [markdown]
# ### Your Work
#
# Add cells here for experimenting with two other color maps from the SciPy wiki list above.
#
# Note that you don't need to repeat the import of matplotlib modules.
#
# Just call imshow() with different arguments in "cmap" color map.

# %% [markdown]
# ## Smoothing Filters
#
# Smooting is often used to reduce noise.

# %% [markdown]
# ### Recursive Gaussian Smoothing
#
# This is a relatively fast filter for smoothing an image along all directions.
#
# Here we are showing off, how cool of equations we can add to the notebook
#
#   $$ SI(x') = \int^\infty_\infty{I(x'-x) e^{-x^2}}$$
#
# We need to specify the Sigma value of the Gaussian function to use.
#
# #### Your work
#
# Experiment with the values of Sigma and see its effect on the image.

# %%
rgsmootherfilter = sitk.SmoothingRecursiveGaussianImageFilter()
rgsmootherfilter.SetSigma(2.5)
rgsmootherfilter.SetNormalizeAcrossScale(1)
rgsmoothedimage  = rgsmootherfilter.Execute(image)

imshow(sitk.GetArrayFromImage(rgsmoothedimage),cmap=cm.gray);

# %% [markdown]
# The parameters of the filter can also be passed directly to the Execute() function as:

# %%
rgsmoothedimage  = rgsmootherfilter.Execute(image,3.5,1)

imshow(sitk.GetArrayFromImage(rgsmoothedimage),cmap=cm.gray);

# %% [markdown]
# ### Median Image Filter
#
# The Median filter is commonly used to provide robust smoothing of an image.
#
# Its main parameter is the size of the neirborhood over which the median of pixels intensities is computed.
#
# The neighborhood size is specified in terms of an integer number representing the radius of a Manhattan distance.
#
# Therefore, a radius of 3 means that we will use a neighborhood of 7x7 pixels: 7 = 3 + 1 + 3
#
# #### Your work
#
# Experiment with the values of the Radius and see the effect on the smoothed image

# %%
medianfilter = sitk.MedianImageFilter()
medianfilter.SetRadius(3)
medianimage  = medianfilter.Execute(image)

imshow(sitk.GetArrayFromImage(medianimage),cmap=cm.gray);

# %% [markdown]
# The parameters of the filter can also be passed directly to the Execute() function. Note that the Radius could be different in the X and Y directions, therefore we must pass an array with two values.

# %%
medianimage  = medianfilter.Execute(image,[3,3])

imshow(sitk.GetArrayFromImage(medianimage),cmap=cm.gray);

# %% [markdown]
# ### Curvature Flow Filter
#
# The Curvature flow filter applies a level set paradigm to the smoothin of a scalar image.
#
# Its main parameters are the TimeStep and NumberOfIterations to use for performing the approximation of a solution to a differential equation.
#
# * Increasing the number of iterations will increase the smoothing
# * Reducing the time stop will improve the precision of the differential equation solution, but would require more iterations to produce the same amount of smoothing.
#
# #### Your work
#
# Experiment with the values of number of iterations and time step size.

# %%
curvatureflowfilter = sitk.CurvatureFlowImageFilter()
curvatureflowfilter.SetTimeStep(0.01)
curvatureflowfilter.SetNumberOfIterations(30)
curvatureflowimage  = curvatureflowfilter.Execute(image)

imshow(sitk.GetArrayFromImage(curvatureflowimage),cmap=cm.gray);

# %% [markdown]
# The parameters of the filter can also be passed directly to the Execute() function as:

# %%
rgsmootherfilter.SetSigma(2.5)

imshow(sitk.GetArrayFromImage(curvatureflowimage),cmap=cm.gray);

# %% [markdown]
# ## Grayscale Morphology
#
# Mathematical Morphology filters can be applied in Grayscale

# %% [markdown]
# ### Grayscale Erosion
#
# Based on a size of neighborhood type defined in the SetKernelType() method, and a neighborhood size defined in the SetKernelRadius() method.

# %%
grayscale_erode_filter = sitk.GrayscaleErodeImageFilter()
grayscale_eroded_image = grayscale_erode_filter.Execute(image)
grayscale_erode_filter.SetKernelRadius(3)
grayscale_erode_filter.SetKernelType(sitk.sitkBall)
imshow(sitk.GetArrayFromImage(grayscale_eroded_image),cmap=cm.gray);

# %% [markdown]
# ### Grayscale Dilation
#
# Based on a size of neighborhood type defined in the SetKernelType() method, and a neighborhood size defined in the SetKernelRadius() method.

# %%
grayscale_dilate_filter = sitk.GrayscaleDilateImageFilter()
grayscale_dilate_image = grayscale_dilate_filter.Execute(image)
grayscale_dilate_filter.SetKernelRadius(3)
grayscale_dilate_filter.SetKernelType(sitk.sitkBall)
imshow(sitk.GetArrayFromImage(grayscale_dilate_image),cmap=cm.gray);

# %% [markdown]
# ## Edge Detection
#
# Filters commonly used in Edge Detection

# %% [markdown]
# ### Canny Edge Detection
#
# The classic Canny filter. We define the lower threshold for edge connections and the Variance of the smoothing component.

# %%
canny_filter = sitk.CannyEdgeDetectionImageFilter()
float_image =  sitk.Cast(image, sitk.sitkFloat32)
canny_filter.SetLowerThreshold(50);
canny_filter.SetVariance(15);
canny_edges = canny_filter.Execute(float_image)
imshow(sitk.GetArrayFromImage(canny_edges),cmap=cm.gray);

# %% [markdown]
# #### Your Work
#
# In the Canny filter above, experiment with other values of
#
# * The Variance
# * The Lower Threshold

# %% [markdown]
# ### Laplacian Recursive
#
# The Laplacian Recursive Image filter is based on the RecursiveGaussianImageFilter, and its second derivatives. We define the Sigma value for the Gaussian.

# %%
rglaplacianfilter = sitk.LaplacianRecursiveGaussianImageFilter()
rglaplacianfilter.SetSigma(2.5)
rglaplacianfilter.SetNormalizeAcrossScale(1)
rglaplacianimage  = rglaplacianfilter.Execute(image)

imshow(sitk.GetArrayFromImage(rglaplacianimage),cmap=cm.gray);

# %% [markdown]
# #### Your Work
#
# In the Laplacian filter above, experiment with other values of
#
# * Sigma

# %% [markdown]
# ## Thresholding Filters
#
# Filters commonly used to threshold images.

# %% [markdown]
# ### Otsu Threshold Image Filter
#
# Computes a threshold value that maximizes the separation between classes in the histogram. Then applies this threshold the image.

# %%
otsu_filter = sitk.OtsuThresholdImageFilter()
otsu_image = otsu_filter.Execute(image)
imshow(sitk.GetArrayFromImage(otsu_image),cmap=cm.gray);

# %% [markdown]
# ## Voting Filters
#
# These filters perform operations on binary images based on the counts (votes) of neighboring pixels.

# %% [markdown]
# ### Hole Filling Filter
#
# This filter is based on a Voting operation. It is useful to remove isolated pixels from the image

# %%
hole_filling_filter = sitk.VotingBinaryHoleFillingImageFilter()
hole_filling_filter.SetRadius(2)
hole_filling_filter.SetMajorityThreshold(1)
hole_filling_filter.SetBackgroundValue(0)
hole_filling_filter.SetForegroundValue(1)
hole_filled_image = hole_filling_filter.Execute(otsu_image)
imshow(sitk.GetArrayFromImage(hole_filled_image),cmap=cm.gray);

# %% [markdown]
# ### Iterative Voting Hole Filling Filter
#
# Performs the filling operation multiple times until no pixels change, or maximum number of iterations is reached.

# %%
hole_filling_filter = sitk.VotingBinaryIterativeHoleFillingImageFilter()
hole_filling_filter.SetRadius(2)
hole_filling_filter.SetMajorityThreshold(1)
hole_filling_filter.SetBackgroundValue(0)
hole_filling_filter.SetForegroundValue(1)
hole_filled_image = hole_filling_filter.Execute(otsu_image)
imshow(sitk.GetArrayFromImage(hole_filled_image),cmap=cm.gray);

# %% [markdown]
# #### Your Work
#
# In the Hole Filling filters above, experiment with the values of:
#
# * Radius
# * Majority Threshold

# %% [markdown]
# # More Filters
#
# Find more filters available in SimpleITK in the following documentation page
#
# http://www.itk.org/SimpleITKDoxygen08/html/namespaceitk_1_1simple.html

# %% [markdown]
# Another way to see the full list of classes available in SimpleITK is to use the dir() function, as in:

# %%
dir(sitk)
# Out:
# ['Abs',
#  'AbsImageFilter',
#  'AbsImageFilter_swigregister',
#  'AbsoluteValueDifference',
#  'AbsoluteValueDifferenceImageFilter',
#  'AbsoluteValueDifferenceImageFilter_swigregister',
#  'Acos',
#  'AcosImageFilter',
#  'AcosImageFilter_swigregister',
#  'AdaptiveHistogramEqualization',
#  'AdaptiveHistogramEqualizationImageFilter',
#  'AdaptiveHistogramEqualizationImageFilter_swigregister',
#  'Add',
#  'AddImageFilter',
#  'AddImageFilter_swigregister',
#  'And',
#  'AndImageFilter',
#  'AndImageFilter_swigregister',
#  'AntiAliasBinary',
#  'AntiAliasBinaryImageFilter',
#  'AntiAliasBinaryImageFilter_swigregister',
#  'ApproximateSignedDistanceMap',
#  'ApproximateSignedDistanceMapImageFilter',
#  'ApproximateSignedDistanceMapImageFilter_swigregister',
#  'Asin',
#  'AsinImageFilter',
#  'AsinImageFilter_swigregister',
#  'Atan',
#  'Atan2',
#  'Atan2ImageFilter',
#  'Atan2ImageFilter_swigregister',
#  'AtanImageFilter',
#  'AtanImageFilter_swigregister',
#  'BasicMeasurementMap',
#  'BasicMeasurementMap_swigregister',
#  'Bilateral',
#  'BilateralImageFilter',
#  'BilateralImageFilter_swigregister',
#  'BinShrink',
#  'BinShrinkImageFilter',
#  'BinShrinkImageFilter_swigregister',
#  'BinaryClosingByReconstruction',
#  'BinaryClosingByReconstructionImageFilter',
#  'BinaryClosingByReconstructionImageFilter_swigregister',
#  'BinaryContour',
#  'BinaryContourImageFilter',
#  'BinaryContourImageFilter_swigregister',
#  'BinaryDilate',
#  'BinaryDilateImageFilter',
#  'BinaryDilateImageFilter_swigregister',
#  'BinaryErode',
#  'BinaryErodeImageFilter',
#  'BinaryErodeImageFilter_swigregister',
#  'BinaryFillhole',
#  'BinaryFillholeImageFilter',
#  'BinaryFillholeImageFilter_swigregister',
#  'BinaryGrindPeak',
#  'BinaryGrindPeakImageFilter',
#  'BinaryGrindPeakImageFilter_swigregister',
#  'BinaryMagnitude',
#  'BinaryMagnitudeImageFilter',
#  'BinaryMagnitudeImageFilter_swigregister',
#  'BinaryMedian',
#  'BinaryMedianImageFilter',
#  'BinaryMedianImageFilter_swigregister',
#  'BinaryMinMaxCurvatureFlow',
#  'BinaryMinMaxCurvatureFlowImageFilter',
#  'BinaryMinMaxCurvatureFlowImageFilter_swigregister',
#  'BinaryMorphologicalClosing',
#  'BinaryMorphologicalClosingImageFilter',
#  'BinaryMorphologicalClosingImageFilter_swigregister',
#  'BinaryMorphologicalOpening',
#  'BinaryMorphologicalOpeningImageFilter',
#  'BinaryMorphologicalOpeningImageFilter_swigregister',
#  'BinaryNot',
#  'BinaryNotImageFilter',
#  'BinaryNotImageFilter_swigregister',
#  'BinaryOpeningByReconstruction',
#  'BinaryOpeningByReconstructionImageFilter',
#  'BinaryOpeningByReconstructionImageFilter_swigregister',
#  'BinaryProjection',
#  'BinaryProjectionImageFilter',
#  'BinaryProjectionImageFilter_swigregister',
#  'BinaryReconstructionByDilation',
#  'BinaryReconstructionByDilationImageFilter',
#  'BinaryReconstructionByDilationImageFilter_swigregister',
#  'BinaryReconstructionByErosion',
#  'BinaryReconstructionByErosionImageFilter',
#  'BinaryReconstructionByErosionImageFilter_swigregister',
#  'BinaryThinning',
#  'BinaryThinningImageFilter',
#  'BinaryThinningImageFilter_swigregister',
#  'BinaryThreshold',
#  'BinaryThresholdImageFilter',
#  'BinaryThresholdImageFilter_swigregister',
#  'BinaryThresholdProjection',
#  'BinaryThresholdProjectionImageFilter',
#  'BinaryThresholdProjectionImageFilter_swigregister',
#  'BinomialBlur',
#  'BinomialBlurImageFilter',
#  'BinomialBlurImageFilter_swigregister',
#  'BitwiseNot',
#  'BitwiseNotImageFilter',
#  'BitwiseNotImageFilter_swigregister',
#  'BlackTopHat',
#  'BlackTopHatImageFilter',
#  'BlackTopHatImageFilter_swigregister',
#  'BoundedReciprocal',
#  'BoundedReciprocalImageFilter',
#  'BoundedReciprocalImageFilter_swigregister',
#  'BoxMean',
#  'BoxMeanImageFilter',
#  'BoxMeanImageFilter_swigregister',
#  'BoxSigma',
#  'BoxSigmaImageFilter',
#  'BoxSigmaImageFilter_swigregister',
#  'CannyEdgeDetection',
#  'CannyEdgeDetectionImageFilter',
#  'CannyEdgeDetectionImageFilter_swigregister',
#  'Cast',
#  'CastImageFilter',
#  'CastImageFilter_swigregister',
#  'ChangeLabel',
#  'ChangeLabelImageFilter',
#  'ChangeLabelImageFilter_swigregister',
#  'CheckerBoard',
#  'CheckerBoardImageFilter',
#  'CheckerBoardImageFilter_swigregister',
#  'Clamp',
#  'ClampImageFilter',
#  'ClampImageFilter_swigregister',
#  'ClosingByReconstruction',
#  'ClosingByReconstructionImageFilter',
#  'ClosingByReconstructionImageFilter_swigregister',
#  'Command',
#  'Command_swigregister',
#  'ComplexToImaginary',
#  'ComplexToImaginaryImageFilter',
#  'ComplexToImaginaryImageFilter_swigregister',
#  'ComplexToModulus',
#  'ComplexToModulusImageFilter',
#  'ComplexToModulusImageFilter_swigregister',
#  'ComplexToPhase',
#  'ComplexToPhaseImageFilter',
#  'ComplexToPhaseImageFilter_swigregister',
#  'ComplexToReal',
#  'ComplexToRealImageFilter',
#  'ComplexToRealImageFilter_swigregister',
#  'Compose',
#  'ComposeImageFilter',
#  'ComposeImageFilter_swigregister',
#  'ConfidenceConnected',
#  'ConfidenceConnectedImageFilter',
#  'ConfidenceConnectedImageFilter_swigregister',
#  'ConnectedComponent',
#  'ConnectedComponentImageFilter',
#  'ConnectedComponentImageFilter_swigregister',
#  'ConnectedThreshold',
#  'ConnectedThresholdImageFilter',
#  'ConnectedThresholdImageFilter_swigregister',
#  'ConstantPad',
#  'ConstantPadImageFilter',
#  'ConstantPadImageFilter_swigregister',
#  'Convolution',
#  'ConvolutionImageFilter',
#  'ConvolutionImageFilter_swigregister',
#  'Cos',
#  'CosImageFilter',
#  'CosImageFilter_swigregister',
#  'Crop',
#  'CropImageFilter',
#  'CropImageFilter_swigregister',
#  'CurvatureAnisotropicDiffusion',
#  'CurvatureAnisotropicDiffusionImageFilter',
#  'CurvatureAnisotropicDiffusionImageFilter_swigregister',
#  'CurvatureFlow',
#  'CurvatureFlowImageFilter',
#  'CurvatureFlowImageFilter_swigregister',
#  'CyclicShift',
#  'CyclicShiftImageFilter',
#  'CyclicShiftImageFilter_swigregister',
#  'DanielssonDistanceMap',
#  'DanielssonDistanceMapImageFilter',
#  'DanielssonDistanceMapImageFilter_swigregister',
#  'Derivative',
#  'DerivativeImageFilter',
#  'DerivativeImageFilter_swigregister',
#  'DilateObjectMorphology',
#  'DilateObjectMorphologyImageFilter',
#  'DilateObjectMorphologyImageFilter_swigregister',
#  'DiscreteGaussian',
#  'DiscreteGaussianDerivative',
#  'DiscreteGaussianDerivativeImageFilter',
#  'DiscreteGaussianDerivativeImageFilter_swigregister',
#  'DiscreteGaussianImageFilter',
#  'DiscreteGaussianImageFilter_swigregister',
#  'Divide',
#  'DivideFloor',
#  'DivideFloorImageFilter',
#  'DivideFloorImageFilter_swigregister',
#  'DivideImageFilter',
#  'DivideImageFilter_swigregister',
#  'DivideReal',
#  'DivideRealImageFilter',
#  'DivideRealImageFilter_swigregister',
#  'DoubleDoubleMap',
#  'DoubleDoubleMap_swigregister',
#  'DoubleThreshold',
#  'DoubleThresholdImageFilter',
#  'DoubleThresholdImageFilter_swigregister',
#  'EdgePotential',
#  'EdgePotentialImageFilter',
#  'EdgePotentialImageFilter_swigregister',
#  'Equal',
#  'EqualImageFilter',
#  'EqualImageFilter_swigregister',
#  'ErodeObjectMorphology',
#  'ErodeObjectMorphologyImageFilter',
#  'ErodeObjectMorphologyImageFilter_swigregister',
#  'Exp',
#  'ExpImageFilter',
#  'ExpImageFilter_swigregister',
#  'ExpNegative',
#  'ExpNegativeImageFilter',
#  'ExpNegativeImageFilter_swigregister',
#  'Expand',
#  'ExpandImageFilter',
#  'ExpandImageFilter_swigregister',
#  'Extract',
#  'ExtractImageFilter',
#  'ExtractImageFilter_swigregister',
#  'FFTConvolution',
#  'FFTConvolutionImageFilter',
#  'FFTConvolutionImageFilter_swigregister',
#  'FFTNormalizedCorrelation',
#  'FFTNormalizedCorrelationImageFilter',
#  'FFTNormalizedCorrelationImageFilter_swigregister',
#  'FFTShift',
#  'FFTShiftImageFilter',
#  'FFTShiftImageFilter_swigregister',
#  'FastApproximateRank',
#  'FastApproximateRankImageFilter',
#  'FastApproximateRankImageFilter_swigregister',
#  'FastMarching',
#  'FastMarchingImageFilter',
#  'FastMarchingImageFilter_swigregister',
#  'Flip',
#  'FlipImageFilter',
#  'FlipImageFilter_swigregister',
#  'ForwardFFT',
#  'ForwardFFTImageFilter',
#  'ForwardFFTImageFilter_swigregister',
#  'GaborImageSource',
#  'GaborImageSource_swigregister',
#  'GaborSource',
#  'GaussianImageSource',
#  'GaussianImageSource_swigregister',
#  'GaussianSource',
#  'GeodesicActiveContourLevelSet',
#  'GeodesicActiveContourLevelSetImageFilter',
#  'GeodesicActiveContourLevelSetImageFilter_swigregister',
#  'GetArrayFromImage',
#  'GetImageFromArray',
#  'GetPixelIDValueAsString',
#  'Gradient',
#  'GradientAnisotropicDiffusion',
#  'GradientAnisotropicDiffusionImageFilter',
#  'GradientAnisotropicDiffusionImageFilter_swigregister',
#  'GradientImageFilter',
#  'GradientImageFilter_swigregister',
#  'GradientMagnitude',
#  'GradientMagnitudeImageFilter',
#  'GradientMagnitudeImageFilter_swigregister',
#  'GradientMagnitudeRecursiveGaussian',
#  'GradientMagnitudeRecursiveGaussianImageFilter',
#  'GradientMagnitudeRecursiveGaussianImageFilter_swigregister',
#  'GradientRecursiveGaussian',
#  'GradientRecursiveGaussianImageFilter',
#  'GradientRecursiveGaussianImageFilter_swigregister',
#  'GrayscaleConnectedClosing',
#  'GrayscaleConnectedClosingImageFilter',
#  'GrayscaleConnectedClosingImageFilter_swigregister',
#  'GrayscaleConnectedOpening',
#  'GrayscaleConnectedOpeningImageFilter',
#  'GrayscaleConnectedOpeningImageFilter_swigregister',
#  'GrayscaleDilate',
#  'GrayscaleDilateImageFilter',
#  'GrayscaleDilateImageFilter_swigregister',
#  'GrayscaleErode',
#  'GrayscaleErodeImageFilter',
#  'GrayscaleErodeImageFilter_swigregister',
#  'GrayscaleFillhole',
#  'GrayscaleFillholeImageFilter',
#  'GrayscaleFillholeImageFilter_swigregister',
#  'GrayscaleGeodesicDilate',
#  'GrayscaleGeodesicDilateImageFilter',
#  'GrayscaleGeodesicDilateImageFilter_swigregister',
#  'GrayscaleGeodesicErode',
#  'GrayscaleGeodesicErodeImageFilter',
#  'GrayscaleGeodesicErodeImageFilter_swigregister',
#  'GrayscaleGrindPeak',
#  'GrayscaleGrindPeakImageFilter',
#  'GrayscaleGrindPeakImageFilter_swigregister',
#  'GrayscaleMorphologicalClosing',
#  'GrayscaleMorphologicalClosingImageFilter',
#  'GrayscaleMorphologicalClosingImageFilter_swigregister',
#  'GrayscaleMorphologicalOpening',
#  'GrayscaleMorphologicalOpeningImageFilter',
#  'GrayscaleMorphologicalOpeningImageFilter_swigregister',
#  'Greater',
#  'GreaterEqual',
#  'GreaterEqualImageFilter',
#  'GreaterEqualImageFilter_swigregister',
#  'GreaterImageFilter',
#  'GreaterImageFilter_swigregister',
#  'GridImageSource',
#  'GridImageSource_swigregister',
#  'GridSource',
#  'HAVE_NUMPY',
#  'HConcave',
#  'HConcaveImageFilter',
#  'HConcaveImageFilter_swigregister',
#  'HConvex',
#  'HConvexImageFilter',
#  'HConvexImageFilter_swigregister',
#  'HMaxima',
#  'HMaximaImageFilter',
#  'HMaximaImageFilter_swigregister',
#  'HMinima',
#  'HMinimaImageFilter',
#  'HMinimaImageFilter_swigregister',
#  'HalfHermitianToRealInverseFFT',
#  'HalfHermitianToRealInverseFFTImageFilter',
#  'HalfHermitianToRealInverseFFTImageFilter_swigregister',
#  'Hash',
#  'HashImageFilter',
#  'HashImageFilter_swigregister',
#  'HausdorffDistance',
#  'HausdorffDistanceImageFilter',
#  'HausdorffDistanceImageFilter_swigregister',
#  'HistogramMatching',
#  'HistogramMatchingImageFilter',
#  'HistogramMatchingImageFilter_swigregister',
#  'HuangThreshold',
#  'HuangThresholdImageFilter',
#  'HuangThresholdImageFilter_swigregister',
#  'Image',
#  'ImageFileReader',
#  'ImageFileReader_swigregister',
#  'ImageFileWriter',
#  'ImageFileWriter_swigregister',
#  'ImageFilterExecuteBase_0',
#  'ImageFilterExecuteBase_0_swigregister',
#  'ImageFilterExecuteBase_1',
#  'ImageFilterExecuteBase_1_swigregister',
#  'ImageFilterExecuteBase_2',
#  'ImageFilterExecuteBase_2_swigregister',
#  'ImageFilterExecuteBase_3',
#  'ImageFilterExecuteBase_3_swigregister',
#  'ImageFilterExecuteBase_4',
#  'ImageFilterExecuteBase_4_swigregister',
#  'ImageFilterExecuteBase_5',
#  'ImageFilterExecuteBase_5_swigregister',
#  'ImageFilter_0',
#  'ImageFilter_0_swigregister',
#  'ImageFilter_1',
#  'ImageFilter_1_swigregister',
#  'ImageFilter_2',
#  'ImageFilter_2_swigregister',
#  'ImageFilter_3',
#  'ImageFilter_3_swigregister',
#  'ImageFilter_4',
#  'ImageFilter_4_swigregister',
#  'ImageFilter_5',
#  'ImageFilter_5_swigregister',
#  'ImageReaderBase',
#  'ImageReaderBase_swigregister',
#  'ImageSeriesReader',
#  'ImageSeriesReader_GetGDCMSeriesFileNames',
#  'ImageSeriesReader_GetGDCMSeriesIDs',
#  'ImageSeriesReader_swigregister',
#  'Image_swigregister',
#  'IntensityWindowing',
#  'IntensityWindowingImageFilter',
#  'IntensityWindowingImageFilter_swigregister',
#  'IntermodesThreshold',
#  'IntermodesThresholdImageFilter',
#  'IntermodesThresholdImageFilter_swigregister',
#  'InverseDeconvolution',
#  'InverseDeconvolutionImageFilter',
#  'InverseDeconvolutionImageFilter_swigregister',
#  'InverseFFT',
#  'InverseFFTImageFilter',
#  'InverseFFTImageFilter_swigregister',
#  'InvertIntensity',
#  'InvertIntensityImageFilter',
#  'InvertIntensityImageFilter_swigregister',
#  'IsoContourDistance',
#  'IsoContourDistanceImageFilter',
#  'IsoContourDistanceImageFilter_swigregister',
#  'IsoDataThreshold',
#  'IsoDataThresholdImageFilter',
#  'IsoDataThresholdImageFilter_swigregister',
#  'IsolatedConnected',
#  'IsolatedConnectedImageFilter',
#  'IsolatedConnectedImageFilter_swigregister',
#  'IsolatedWatershed',
#  'IsolatedWatershedImageFilter',
#  'IsolatedWatershedImageFilter_swigregister',
#  'JoinSeries',
#  'JoinSeriesImageFilter',
#  'JoinSeriesImageFilter_swigregister',
#  'KittlerIllingworthThreshold',
#  'KittlerIllingworthThresholdImageFilter',
#  'KittlerIllingworthThresholdImageFilter_swigregister',
#  'LabelContour',
#  'LabelContourImageFilter',
#  'LabelContourImageFilter_swigregister',
#  'LabelMapContourOverlay',
#  'LabelMapContourOverlayImageFilter',
#  'LabelMapContourOverlayImageFilter_swigregister',
#  'LabelMapMask',
#  'LabelMapMaskImageFilter',
#  'LabelMapMaskImageFilter_swigregister',
#  'LabelMapOverlay',
#  'LabelMapOverlayImageFilter',
#  'LabelMapOverlayImageFilter_swigregister',
#  'LabelMapToBinary',
#  'LabelMapToBinaryImageFilter',
#  'LabelMapToBinaryImageFilter_swigregister',
#  'LabelMapToLabel',
#  'LabelMapToLabelImageFilter',
#  'LabelMapToLabelImageFilter_swigregister',
#  'LabelMapToRGB',
#  'LabelMapToRGBImageFilter',
#  'LabelMapToRGBImageFilter_swigregister',
#  'LabelOverlay',
#  'LabelOverlayImageFilter',
#  'LabelOverlayImageFilter_swigregister',
#  'LabelStatistics',
#  'LabelStatisticsImageFilter',
#  'LabelStatisticsImageFilter_swigregister',
#  'LabelToRGB',
#  'LabelToRGBImageFilter',
#  'LabelToRGBImageFilter_swigregister',
#  'LabelVoting',
#  'LabelVotingImageFilter',
#  'LabelVotingImageFilter_swigregister',
#  'LandweberDeconvolution',
#  'LandweberDeconvolutionImageFilter',
#  'LandweberDeconvolutionImageFilter_swigregister',
#  'Laplacian',
#  'LaplacianImageFilter',
#  'LaplacianImageFilter_swigregister',
#  'LaplacianRecursiveGaussian',
#  'LaplacianRecursiveGaussianImageFilter',
#  'LaplacianRecursiveGaussianImageFilter_swigregister',
#  'LaplacianSegmentationLevelSet',
#  'LaplacianSegmentationLevelSetImageFilter',
#  'LaplacianSegmentationLevelSetImageFilter_swigregister',
#  'LaplacianSharpening',
#  'LaplacianSharpeningImageFilter',
#  'LaplacianSharpeningImageFilter_swigregister',
#  'Less',
#  'LessEqual',
#  'LessEqualImageFilter',
#  'LessEqualImageFilter_swigregister',
#  'LessImageFilter',
#  'LessImageFilter_swigregister',
#  'LiThreshold',
#  'LiThresholdImageFilter',
#  'LiThresholdImageFilter_swigregister',
#  'Log',
#  'Log10',
#  'Log10ImageFilter',
#  'Log10ImageFilter_swigregister',
#  'LogImageFilter',
#  'LogImageFilter_swigregister',
#  'MagnitudeAndPhaseToComplex',
#  'MagnitudeAndPhaseToComplexImageFilter',
#  'MagnitudeAndPhaseToComplexImageFilter_swigregister',
#  'Mask',
#  'MaskImageFilter',
#  'MaskImageFilter_swigregister',
#  'MaskNegated',
#  'MaskNegatedImageFilter',
#  'MaskNegatedImageFilter_swigregister',
#  'MaskedFFTNormalizedCorrelation',
#  'MaskedFFTNormalizedCorrelationImageFilter',
#  'MaskedFFTNormalizedCorrelationImageFilter_swigregister',
#  'Maximum',
#  'MaximumEntropyThreshold',
#  'MaximumEntropyThresholdImageFilter',
#  'MaximumEntropyThresholdImageFilter_swigregister',
#  'MaximumImageFilter',
#  'MaximumImageFilter_swigregister',
#  'MaximumProjection',
#  'MaximumProjectionImageFilter',
#  'MaximumProjectionImageFilter_swigregister',
#  'Mean',
#  'MeanImageFilter',
#  'MeanImageFilter_swigregister',
#  'MeanProjection',
#  'MeanProjectionImageFilter',
#  'MeanProjectionImageFilter_swigregister',
#  'MeasurementMap',
#  'MeasurementMap_swigregister',
#  'Median',
#  'MedianImageFilter',
#  'MedianImageFilter_swigregister',
#  'MedianProjection',
#  'MedianProjectionImageFilter',
#  'MedianProjectionImageFilter_swigregister',
#  'MinMaxCurvatureFlow',
#  'MinMaxCurvatureFlowImageFilter',
#  'MinMaxCurvatureFlowImageFilter_swigregister',
#  'Minimum',
#  'MinimumImageFilter',
#  'MinimumImageFilter_swigregister',
#  'MinimumMaximum',
#  'MinimumMaximumImageFilter',
#  'MinimumMaximumImageFilter_swigregister',
#  'MinimumProjection',
#  'MinimumProjectionImageFilter',
#  'MinimumProjectionImageFilter_swigregister',
#  'MirrorPad',
#  'MirrorPadImageFilter',
#  'MirrorPadImageFilter_swigregister',
#  'Modulus',
#  'ModulusImageFilter',
#  'ModulusImageFilter_swigregister',
#  'MomentsThreshold',
#  'MomentsThresholdImageFilter',
#  'MomentsThresholdImageFilter_swigregister',
#  'MorphologicalGradient',
#  'MorphologicalGradientImageFilter',
#  'MorphologicalGradientImageFilter_swigregister',
#  'MorphologicalWatershed',
#  'MorphologicalWatershedFromMarkers',
#  'MorphologicalWatershedFromMarkersImageFilter',
#  'MorphologicalWatershedFromMarkersImageFilter_swigregister',
#  'MorphologicalWatershedImageFilter',
#  'MorphologicalWatershedImageFilter_swigregister',
#  'Multiply',
#  'MultiplyImageFilter',
#  'MultiplyImageFilter_swigregister',
#  'N4BiasFieldCorrection',
#  'N4BiasFieldCorrectionImageFilter',
#  'N4BiasFieldCorrectionImageFilter_swigregister',
#  'NaryAdd',
#  'NaryAddImageFilter',
#  'NaryAddImageFilter_swigregister',
#  'NaryMaximum',
#  'NaryMaximumImageFilter',
#  'NaryMaximumImageFilter_swigregister',
#  'NeighborhoodConnected',
#  'NeighborhoodConnectedImageFilter',
#  'NeighborhoodConnectedImageFilter_swigregister',
#  'Noise',
#  'NoiseImageFilter',
#  'NoiseImageFilter_swigregister',
#  'Normalize',
#  'NormalizeImageFilter',
#  'NormalizeImageFilter_swigregister',
#  'NormalizeToConstant',
#  'NormalizeToConstantImageFilter',
#  'NormalizeToConstantImageFilter_swigregister',
#  'NormalizedCorrelation',
#  'NormalizedCorrelationImageFilter',
#  'NormalizedCorrelationImageFilter_swigregister',
#  'Not',
#  'NotEqual',
#  'NotEqualImageFilter',
#  'NotEqualImageFilter_swigregister',
#  'NotImageFilter',
#  'NotImageFilter_swigregister',
#  'OpeningByReconstruction',
#  'OpeningByReconstructionImageFilter',
#  'OpeningByReconstructionImageFilter_swigregister',
#  'Or',
#  'OrImageFilter',
#  'OrImageFilter_swigregister',
#  'OtsuMultipleThresholds',
#  'OtsuMultipleThresholdsImageFilter',
#  'OtsuMultipleThresholdsImageFilter_swigregister',
#  'OtsuThreshold',
#  'OtsuThresholdImageFilter',
#  'OtsuThresholdImageFilter_swigregister',
#  'Paste',
#  'PasteImageFilter',
#  'PasteImageFilter_swigregister',
#  'PatchBasedDenoising',
#  'PatchBasedDenoisingImageFilter',
#  'PatchBasedDenoisingImageFilter_swigregister',
#  'PermuteAxes',
#  'PermuteAxesImageFilter',
#  'PermuteAxesImageFilter_swigregister',
#  'PhysicalPointImageSource',
#  'PhysicalPointImageSource_swigregister',
#  'PhysicalPointSource',
#  'Pow',
#  'PowImageFilter',
#  'PowImageFilter_swigregister',
#  'ProcessObject',
#  'ProcessObject_GetGlobalDefaultDebug',
#  'ProcessObject_GetGlobalDefaultNumberOfThreads',
#  'ProcessObject_GetGlobalWarningDisplay',
#  'ProcessObject_GlobalDefaultDebugOff',
#  'ProcessObject_GlobalDefaultDebugOn',
#  'ProcessObject_GlobalWarningDisplayOff',
#  'ProcessObject_GlobalWarningDisplayOn',
#  'ProcessObject_SetGlobalDefaultDebug',
#  'ProcessObject_SetGlobalDefaultNumberOfThreads',
#  'ProcessObject_SetGlobalWarningDisplay',
#  'ProcessObject_swigregister',
#  'ProjectedLandweberDeconvolution',
#  'ProjectedLandweberDeconvolutionImageFilter',
#  'ProjectedLandweberDeconvolutionImageFilter_swigregister',
#  'PyCommand',
#  'PyCommand_swigregister',
#  'Rank',
#  'RankImageFilter',
#  'RankImageFilter_swigregister',
#  'ReadImage',
#  'ReadTransform',
#  'RealAndImaginaryToComplex',
#  'RealAndImaginaryToComplexImageFilter',
#  'RealAndImaginaryToComplexImageFilter_swigregister',
#  'RealToHalfHermitianForwardFFT',
#  'RealToHalfHermitianForwardFFTImageFilter',
#  'RealToHalfHermitianForwardFFTImageFilter_swigregister',
#  'ReconstructionByDilation',
#  'ReconstructionByDilationImageFilter',
#  'ReconstructionByDilationImageFilter_swigregister',
#  'ReconstructionByErosion',
#  'ReconstructionByErosionImageFilter',
#  'ReconstructionByErosionImageFilter_swigregister',
#  'RecursiveGaussian',
#  'RecursiveGaussianImageFilter',
#  'RecursiveGaussianImageFilter_swigregister',
#  'RegionOfInterest',
#  'RegionOfInterestImageFilter',
#  'RegionOfInterestImageFilter_swigregister',
#  'RegionalMaxima',
#  'RegionalMaximaImageFilter',
#  'RegionalMaximaImageFilter_swigregister',
#  'RegionalMinima',
#  'RegionalMinimaImageFilter',
#  'RegionalMinimaImageFilter_swigregister',
#  'RelabelComponent',
#  'RelabelComponentImageFilter',
#  'RelabelComponentImageFilter_swigregister',
#  'RenyiEntropyThreshold',
#  'RenyiEntropyThresholdImageFilter',
#  'RenyiEntropyThresholdImageFilter_swigregister',
#  'Resample',
#  'ResampleImageFilter',
#  'ResampleImageFilter_swigregister',
#  'RescaleIntensity',
#  'RescaleIntensityImageFilter',
#  'RescaleIntensityImageFilter_swigregister',
#  'RichardsonLucyDeconvolution',
#  'RichardsonLucyDeconvolutionImageFilter',
#  'RichardsonLucyDeconvolutionImageFilter_swigregister',
#  'STAPLE',
#  'STAPLEImageFilter',
#  'STAPLEImageFilter_swigregister',
#  'ScalarChanAndVeseDenseLevelSet',
#  'ScalarChanAndVeseDenseLevelSetImageFilter',
#  'ScalarChanAndVeseDenseLevelSetImageFilter_swigregister',
#  'ScalarConnectedComponent',
#  'ScalarConnectedComponentImageFilter',
#  'ScalarConnectedComponentImageFilter_swigregister',
#  'ScalarImageKmeans',
#  'ScalarImageKmeansImageFilter',
#  'ScalarImageKmeansImageFilter_swigregister',
#  'ScalarToRGBColormap',
#  'ScalarToRGBColormapImageFilter',
#  'ScalarToRGBColormapImageFilter_swigregister',
#  'ShanbhagThreshold',
#  'ShanbhagThresholdImageFilter',
#  'ShanbhagThresholdImageFilter_swigregister',
#  'ShapeDetectionLevelSet',
#  'ShapeDetectionLevelSetImageFilter',
#  'ShapeDetectionLevelSetImageFilter_swigregister',
#  'ShiftScale',
#  'ShiftScaleImageFilter',
#  'ShiftScaleImageFilter_swigregister',
#  'Show',
#  'Shrink',
#  'ShrinkImageFilter',
#  'ShrinkImageFilter_swigregister',
#  'Sigmoid',
#  'SigmoidImageFilter',
#  'SigmoidImageFilter_swigregister',
#  'SignedDanielssonDistanceMap',
#  'SignedDanielssonDistanceMapImageFilter',
#  'SignedDanielssonDistanceMapImageFilter_swigregister',
#  'SignedMaurerDistanceMap',
#  'SignedMaurerDistanceMapImageFilter',
#  'SignedMaurerDistanceMapImageFilter_swigregister',
#  'SimilarityIndex',
#  'SimilarityIndexImageFilter',
#  'SimilarityIndexImageFilter_swigregister',
#  'SimpleContourExtractor',
#  'SimpleContourExtractorImageFilter',
#  'SimpleContourExtractorImageFilter_swigregister',
#  'SimpleITK',
#  'Sin',
#  'SinImageFilter',
#  'SinImageFilter_swigregister',
#  'Slice',
#  'SliceImageFilter',
#  'SliceImageFilter_swigregister',
#  'SmoothingRecursiveGaussian',
#  'SmoothingRecursiveGaussianImageFilter',
#  'SmoothingRecursiveGaussianImageFilter_swigregister',
#  'SobelEdgeDetection',
#  'SobelEdgeDetectionImageFilter',
#  'SobelEdgeDetectionImageFilter_swigregister',
#  'Sqrt',
#  'SqrtImageFilter',
#  'SqrtImageFilter_swigregister',
#  'Square',
#  'SquareImageFilter',
#  'SquareImageFilter_swigregister',
#  'SquaredDifference',
#  'SquaredDifferenceImageFilter',
#  'SquaredDifferenceImageFilter_swigregister',
#  'StandardDeviationProjection',
#  'StandardDeviationProjectionImageFilter',
#  'StandardDeviationProjectionImageFilter_swigregister',
#  'Statistics',
#  'StatisticsImageFilter',
#  'StatisticsImageFilter_swigregister',
#  'Subtract',
#  'SubtractImageFilter',
#  'SubtractImageFilter_swigregister',
#  'SumProjection',
#  'SumProjectionImageFilter',
#  'SumProjectionImageFilter_swigregister',
#  'SwigPyIterator',
#  'SwigPyIterator_swigregister',
#  'Tan',
#  'TanImageFilter',
#  'TanImageFilter_swigregister',
#  'TernaryAdd',
#  'TernaryAddImageFilter',
#  'TernaryAddImageFilter_swigregister',
#  'TernaryMagnitude',
#  'TernaryMagnitudeImageFilter',
#  'TernaryMagnitudeImageFilter_swigregister',
#  'TernaryMagnitudeSquared',
#  'TernaryMagnitudeSquaredImageFilter',
#  'TernaryMagnitudeSquaredImageFilter_swigregister',
#  'Threshold',
#  'ThresholdImageFilter',
#  'ThresholdImageFilter_swigregister',
#  'ThresholdMaximumConnectedComponents',
#  'ThresholdMaximumConnectedComponentsImageFilter',
#  'ThresholdMaximumConnectedComponentsImageFilter_swigregister',
#  'ThresholdSegmentationLevelSet',
#  'ThresholdSegmentationLevelSetImageFilter',
#  'ThresholdSegmentationLevelSetImageFilter_swigregister',
#  'TikhonovDeconvolution',
#  'TikhonovDeconvolutionImageFilter',
#  'TikhonovDeconvolutionImageFilter_swigregister',
#  'Tile',
#  'TileImageFilter',
#  'TileImageFilter_swigregister',
#  'Transform',
#  'Transform_swigregister',
#  'TriangleThreshold',
#  'TriangleThresholdImageFilter',
#  'TriangleThresholdImageFilter_swigregister',
#  'UnaryMinus',
#  'UnaryMinusImageFilter',
#  'UnaryMinusImageFilter_swigregister',
#  'ValuedRegionalMaxima',
#  'ValuedRegionalMaximaImageFilter',
#  'ValuedRegionalMaximaImageFilter_swigregister',
#  'ValuedRegionalMinima',
#  'ValuedRegionalMinimaImageFilter',
#  'ValuedRegionalMinimaImageFilter_swigregister',
#  'VectorBool',
#  'VectorBool_swigregister',
#  'VectorConfidenceConnected',
#  'VectorConfidenceConnectedImageFilter',
#  'VectorConfidenceConnectedImageFilter_swigregister',
#  'VectorConnectedComponent',
#  'VectorConnectedComponentImageFilter',
#  'VectorConnectedComponentImageFilter_swigregister',
#  'VectorDouble',
#  'VectorDouble_swigregister',
#  'VectorFloat',
#  'VectorFloat_swigregister',
#  'VectorIndexSelectionCast',
#  'VectorIndexSelectionCastImageFilter',
#  'VectorIndexSelectionCastImageFilter_swigregister',
#  'VectorInt16',
#  'VectorInt16_swigregister',
#  'VectorInt32',
#  'VectorInt32_swigregister',
#  'VectorInt64',
#  'VectorInt64_swigregister',
#  'VectorInt8',
#  'VectorInt8_swigregister',
#  'VectorMagnitude',
#  'VectorMagnitudeImageFilter',
#  'VectorMagnitudeImageFilter_swigregister',
#  'VectorOfImage',
#  'VectorOfImage_swigregister',
#  'VectorString',
#  'VectorString_swigregister',
#  'VectorUInt16',
#  'VectorUInt16_swigregister',
#  'VectorUInt32',
#  'VectorUInt32_swigregister',
#  'VectorUInt64',
#  'VectorUInt64_swigregister',
#  'VectorUInt8',
#  'VectorUInt8_swigregister',
#  'VectorUIntList',
#  'VectorUIntList_swigregister',
#  'Version',
#  'Version_BuildDate',
#  'Version_ExtendedVersionString',
#  'Version_MajorVersion',
#  'Version_MinorVersion',
#  'Version_PatchVersion',
#  'Version_TweakVersion',
#  'Version_VersionString',
#  'Version_swigregister',
#  'VotingBinary',
#  'VotingBinaryHoleFilling',
#  'VotingBinaryHoleFillingImageFilter',
#  'VotingBinaryHoleFillingImageFilter_swigregister',
#  'VotingBinaryImageFilter',
#  'VotingBinaryImageFilter_swigregister',
#  'VotingBinaryIterativeHoleFilling',
#  'VotingBinaryIterativeHoleFillingImageFilter',
#  'VotingBinaryIterativeHoleFillingImageFilter_swigregister',
#  'Warp',
#  'WarpImageFilter',
#  'WarpImageFilter_swigregister',
#  'WhiteTopHat',
#  'WhiteTopHatImageFilter',
#  'WhiteTopHatImageFilter_swigregister',
#  'WienerDeconvolution',
#  'WienerDeconvolutionImageFilter',
#  'WienerDeconvolutionImageFilter_swigregister',
#  'WrapPad',
#  'WrapPadImageFilter',
#  'WrapPadImageFilter_swigregister',
#  'WriteImage',
#  'WriteTransform',
#  'Xor',
#  'XorImageFilter',
#  'XorImageFilter_swigregister',
#  'YenThreshold',
#  'YenThresholdImageFilter',
#  'YenThresholdImageFilter_swigregister',
#  'ZeroCrossing',
#  'ZeroCrossingBasedEdgeDetection',
#  'ZeroCrossingBasedEdgeDetectionImageFilter',
#  'ZeroCrossingBasedEdgeDetectionImageFilter_swigregister',
#  'ZeroCrossingImageFilter',
#  'ZeroCrossingImageFilter_swigregister',
#  'ZeroFluxNeumannPad',
#  'ZeroFluxNeumannPadImageFilter',
#  'ZeroFluxNeumannPadImageFilter_swigregister',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '__path__',
#  'cvar',
#  'numpy',
#  'operator',
#  'sitkAbortEvent',
#  'sitkAffine',
#  'sitkAnnulus',
#  'sitkAnyEvent',
#  'sitkBSpline',
#  'sitkBall',
#  'sitkBlackmanWindowedSinc',
#  'sitkBox',
#  'sitkComplexFloat32',
#  'sitkComplexFloat64',
#  'sitkComposite',
#  'sitkCosineWindowedSinc',
#  'sitkCross',
#  'sitkDeleteEvent',
#  'sitkEndEvent',
#  'sitkEuler',
#  'sitkFloat32',
#  'sitkFloat64',
#  'sitkGaussian',
#  'sitkHammingWindowedSinc',
#  'sitkIdentity',
#  'sitkInt16',
#  'sitkInt32',
#  'sitkInt64',
#  'sitkInt8',
#  'sitkIterationEvent',
#  'sitkLabelGaussian',
#  'sitkLabelUInt16',
#  'sitkLabelUInt32',
#  'sitkLabelUInt64',
#  'sitkLabelUInt8',
#  'sitkLanczosWindowedSinc',
#  'sitkLinear',
#  'sitkNearestNeighbor',
#  'sitkPolygon3',
#  'sitkPolygon4',
#  'sitkPolygon5',
#  'sitkPolygon6',
#  'sitkPolygon7',
#  'sitkPolygon8',
#  'sitkPolygon9',
#  'sitkProgressEvent',
#  'sitkQuaternionRigid',
#  'sitkScale',
#  'sitkScaleLogarithmic',
#  'sitkSimilarity',
#  'sitkStartEvent',
#  'sitkTranslation',
#  'sitkUInt16',
#  'sitkUInt32',
#  'sitkUInt64',
#  'sitkUInt8',
#  'sitkUnknown',
#  'sitkUserEvent',
#  'sitkVectorFloat32',
#  'sitkVectorFloat64',
#  'sitkVectorInt16',
#  'sitkVectorInt32',
#  'sitkVectorInt64',
#  'sitkVectorInt8',
#  'sitkVectorUInt16',
#  'sitkVectorUInt32',
#  'sitkVectorUInt64',
#  'sitkVectorUInt8',
#  'sitkVersor',
#  'sitkVersorRigid',
#  'sitkWelchWindowedSinc',
#  'sys',
#  'weakref',
#  'weakref_proxy']
