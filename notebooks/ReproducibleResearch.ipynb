# %%
import SimpleITK as sitk

# %%
import urllib
urllib.urlretrieve('http://lh4.ggpht.com/-WuMqHSMMNg4/UrrYQcSoPsI/AAAAAAAAEzo/yB90ioi3-Ig/IMG_20131224_231544.jpg','/tmp/3dprinter.jpg')
# Out:
# ('/tmp/3dprinter.jpg', <httplib.HTTPMessage instance at 0x3e18248>)

# %%
reader = sitk.ImageFileReader()
reader.SetFileName('/tmp/3dprinter.jpg')
image = reader.Execute()

# %%
print image.GetSize()
# Out:
# (512, 384)

# %%
imshow(sitk.GetArrayFromImage(image))
